# %%
import pandas as pd
import json
import glob
from scipy import stats
import itertools
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from matplotlib import font_manager
font_path = '/Users/abhik_bhattacharjee/Desktop/TextAnalytics/newcomputermodern/NewCM10-Regular.otf'
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()

import warnings
warnings.filterwarnings('ignore')

# %%
meanLikert = pd.read_excel("MULTISIMO Corpus - Questionnaire - Likert Scale (Responses).xlsx", 
                           sheet_name="Pivot-Mean")
medianLikert = pd.read_excel("MULTISIMO Corpus - Questionnaire - Likert Scale (Responses).xlsx", 
                             sheet_name="Pivot-Median")
stdDevLikert = pd.read_excel("MULTISIMO Corpus - Questionnaire - Likert Scale (Responses).xlsx", 
                             sheet_name="Pivot-StdDev")
rawResponse = pd.read_excel("MULTISIMO Corpus - Questionnaire - Likert Scale (Responses).xlsx", 
                             sheet_name="Form responses 1")

# %%
rawResponseNew = rawResponse

# %%
medianLikertNew = medianLikert.set_index('Question').T

# %%
dict1 = {}
for i in medianLikertNew.index:
    dict1[i] = medianLikertNew[medianLikertNew.keys()[0]][i]

dict2 = {}
for i in medianLikertNew.index:
    dict2[i] = medianLikertNew[medianLikertNew.keys()[1]][i]

dict3 = {}
for i in medianLikertNew.index:
    dict3[i] = medianLikertNew[medianLikertNew.keys()[2]][i]

dict4 = {}
for i in medianLikertNew.index:
    dict4[i] = medianLikertNew[medianLikertNew.keys()[3]][i]

dict5 = {}
for i in medianLikertNew.index:
    dict5[i] = medianLikertNew[medianLikertNew.keys()[4]][i]

dict6 = {}
for i in medianLikertNew.index:
    dict6[i] = medianLikertNew[medianLikertNew.keys()[5]][i]
    
dict7 = {}
for i in medianLikertNew.index:
    dict7[i] = medianLikertNew[medianLikertNew.keys()[6]][i]

dict8 = {}
for i in medianLikertNew.index:
    dict8[i] = medianLikertNew[medianLikertNew.keys()[7]][i]

dict9 = {}
for i in medianLikertNew.index:
    dict9[i] = medianLikertNew[medianLikertNew.keys()[8]][i]
    
dict10 = {}
for i in medianLikertNew.index:
    dict10[i] = medianLikertNew[medianLikertNew.keys()[9]][i]
    
dict11 = {}
for i in medianLikertNew.index:
    dict11[i] = medianLikertNew[medianLikertNew.keys()[10]][i]

# %%
for i in range(len(rawResponseNew)):
    rawResponseNew[rawResponseNew.keys()[6]][i] = abs(dict1[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[6]][i])
    rawResponseNew[rawResponseNew.keys()[7]][i] = abs(dict2[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[7]][i])
    rawResponseNew[rawResponseNew.keys()[8]][i] = abs(dict3[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[8]][i])
    rawResponseNew[rawResponseNew.keys()[9]][i] = abs(dict4[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[9]][i])
    rawResponseNew[rawResponseNew.keys()[10]][i] = abs(dict5[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[10]][i])
    rawResponseNew[rawResponseNew.keys()[11]][i] = abs(dict6[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[11]][i])
    rawResponseNew[rawResponseNew.keys()[12]][i] = abs(dict7[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[12]][i])
    rawResponseNew[rawResponseNew.keys()[13]][i] = abs(dict8[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[13]][i])
    rawResponseNew[rawResponseNew.keys()[14]][i] = abs(dict9[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[14]][i])
    rawResponseNew[rawResponseNew.keys()[15]][i] = abs(dict10[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[15]][i])
    rawResponseNew[rawResponseNew.keys()[16]][i] = abs(dict11[rawResponseNew[rawResponseNew.keys()[2]][i]] 
                                                      - rawResponseNew[rawResponseNew.keys()[16]][i])

# %%
rawResponseNew
# Out:
#                  Timestamp     Team Member Name  \
# 0  2023-03-27 19:52:45.193  Abhik Bhattacharjee
# 1  2023-03-27 20:13:30.718  Abhik Bhattacharjee
# 2  2023-03-27 23:39:03.083              RUIZHAO
# 3  2023-03-27 23:46:14.830              RUIZHAO
# 4  2023-03-27 23:50:44.591             RUI ZHAO
# ..                     ...                  ...
# 66 2023-03-29 12:01:42.969              Sumanth
# 67 2023-03-29 12:10:23.402              Sumanth
# 68 2023-03-29 12:15:11.001              Sumanth
# 69 2023-03-29 12:20:07.082              Sumanth
# 70 2023-03-29 12:24:19.669              Sumanth
#
#    Please select the Discussion Analysed  \
# 0                                    S02
# 1                                    S03
# 2                                    S02
# 3                                    S03
# 4                                    S04
# ..                                   ...
# 66                                   S19
# 67                                   S20
# ...

# %%
test = rawResponseNew.groupby(['Please select the Discussion Analysed']).sum()/4

# %%
test.to_excel("rawResponseNew.xlsx", index = False)

# %%
test
# Out:
#                                        Are you satisfied with the level of collaboration within the group?  \
# Please select the Discussion Analysed
# S02                                                                                 0.25
# S03                                                                                 0.50
# S04                                                                                 1.00
# S05                                                                                 1.00
# S07                                                                                 0.50
# S08                                                                                 1.00
# S09                                                                                 0.25
# S10                                                                                 0.50
# S11                                                                                 1.00
# ...
